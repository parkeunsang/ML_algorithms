# %% [markdown]
# ### arima example

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats
import statsmodels.api as sm
import warnings
from itertools import product
from datetime import datetime
warnings.filterwarnings('ignore')

# %%
import FinanceDataReader as fdr

# %%
import matplotlib.pyplot as plt

# %%
df = fdr.DataReader('005930', '2018')

# %%
df = df[df.index >='2019']

# %%
plt.plot(df.index,df['Open'])

# %% [markdown]
# Stationarity check and STL-decomposition of the series

# %%
df.index=pd.to_datetime(df.index)

# %%
sm.tsa.stattools.adfuller(df.Close)[1]
# Out:
# 0.11636377954014288

# %%
#sm.tsa.seasonal_decompose(df.Close,freq=30).plot()

# %%
#stats.boxcox(df.Close)

# %% [markdown]
# ### time series

# %% [markdown]
# https://m.blog.naver.com/bluefish850/220749045909

# %% [markdown]
# 1. autocorrelation :

# %% [markdown]
# AR(1) : $X(t) = \{a\cdot X(t-1)+c\} + u \cdot e(t),\ e\sim N(0,1)$

# %% [markdown]
# MA(1) : $X(t) = \{a\cdot e(t-1)+c\} + u \cdot e(t)$
